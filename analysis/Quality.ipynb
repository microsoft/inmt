# %%
import pandas as pd
import re
import ast
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import levene
import matplotlib.pyplot as plt

# %%
trans_pairs = pd.read_csv('data/mt.trans_pairs.csv')
trans_pairs.head()
# Out:
#      id                                      translatedSet  \
# 0  8698  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 1  8697  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 2  8696  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 3  8695  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 4  8694  Test User 401 | Turtle Story PE L4 | Hindi -> ...
#
#                                                  src  \
# 0                                               कछुआ
# 1  सुबह जब मेरी आँख खुली तो आसमान में सूरज चम - च...
# 2                   हैरान होकर मैंने अपने आसपास देखा
# 3  पहले तो चकरा गई कि मैं हूँ कहाँ फिर एकदम याद आ...
# 4  एक असीम नीले संसार के बीचोंबीच , जिसे लोग सागर...
#
#                                                  tgt
# 0                                          Tortoise.
# 1  When my eyes opened in the morning, the sun wa...
# 2                Surprised, I looked around myself.
# 3  First I was wondering where I was, then I reme...
# 4  In the middle of an infinite blue world, which...

# %%
trans_pairs[trans_pairs['src'] == 'हैरान होकर मैंने अपने आसपास देखा']
# Out:
#          id                                      translatedSet  \
# 2      8696  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 253    8445  Test User | Turtle Story PE L4 | Hindi -> English
# 584    8110  Test User 601 | Turtle Story PE L4 | Hindi -> ...
# 625    8069  Test User 501 | Turtle Story PE L4 | Hindi -> ...
# 861    7833      Admin | Turtle Story PE L4 | Hindi -> English
# 3036   4848  Test User 1401 | Turtle Story BL L4 | Hindi ->...
# 3402   4216  Test User 1601 | Turtle Story BL L4 | Hindi ->...
# 3615   4003  Test User 1301 | Turtle Story BL L4 | Hindi ->...
# 5063  10826  Test User 301 | Turtle Story PE L4 | Hindi -> ...
# 5721  10168  Test User 801 | Turtle Story MT L4 | Hindi -> ...
# 5879  10010  Test User 1001 | Turtle Story MT L4 | Hindi ->...
# 6133   9756  Test User 901 | Turtle Story MT L4 | Hindi -> ...
# 6211   9640  Test User 701 | Turtle Story MT L4 | Hindi -> ...
# 6252   9599  Test User 1101 | Turtle Story MT L4 | Hindi ->...
# 6672   9104      Admin | Turtle Story MT L4 | Hindi -> English
#
#                                    src                                    tgt
# 2     हैरान होकर मैंने अपने आसपास देखा    Surprised, I looked around myself.
# 253   हैरान होकर मैंने अपने आसपास देखा    Astonished, I looked around myself.
# 584   हैरान होकर मैंने अपने आसपास देखा        Suddenly i looked around myself
# 625   हैरान होकर मैंने अपने आसपास देखा       Surprisedly, I looked around me.
# 861   हैरान होकर मैंने अपने आसपास देखा                                    NaN
# 3036  हैरान होकर मैंने अपने आसपास देखा  With anxious look I looked around me.
# 3402  हैरान होकर मैंने अपने आसपास देखा   I was surprised. I looked around me.
# 3615  हैरान होकर मैंने अपने आसपास देखा                                    NaN
# 5063  हैरान होकर मैंने अपने आसपास देखा                                    NaN
# 5721  हैरान होकर मैंने अपने आसपास देखा       I looked around with surprise .
# 5879  हैरान होकर मैंने अपने आसपास देखा                                    NaN
# 6133  हैरान होकर मैंने अपने आसपास देखा          Surprised I looked around me
# 6211  हैरान होकर मैंने अपने आसपास देखा           Surprised I looked around me
# 6252  हैरान होकर मैंने अपने आसपास देखा           Surprised I look around me .
# 6672  हैरान होकर मैंने अपने आसपास देखा                                    NaN

# %%
import spacy
nlp = spacy.load("en_core_web_lg")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-5469aec04266> in <module>
#       1 import spacy
# ----> 2 nlp = spacy.load("en_core_web_lg")
#
# ~/.local/lib/python3.6/site-packages/spacy/__init__.py in load(name, **overrides)
#      25     if depr_path not in (True, False, None):
#      26         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 27     return util.load_model(name, **overrides)
#      28
#      29
#
# ~/.local/lib/python3.6/site-packages/spacy/util.py in load_model(name, **overrides)
#     169     elif hasattr(name, "exists"):  # Path or Path-like to model data
#     170         return load_model_from_path(name, **overrides)
# --> 171     raise IOError(Errors.E050.format(name=name))
#     172
#     173
#
# OSError: [E050] Can't find model 'en_core_web_lg'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.
