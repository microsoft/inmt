# %%
import pandas as pd
import re
import ast
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import levene
import matplotlib.pyplot as plt

# %%
trans_pairs = pd.read_csv('data/mt.trans_pairs.csv')
trans_pairs.head()
# Out:
#      id                                      translatedSet  \
# 0  8698  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 1  8697  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 2  8696  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 3  8695  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 4  8694  Test User 401 | Turtle Story PE L4 | Hindi -> ...
#
#                                                  src  \
# 0                                               कछुआ
# 1  सुबह जब मेरी आँख खुली तो आसमान में सूरज चम - च...
# 2                   हैरान होकर मैंने अपने आसपास देखा
# 3  पहले तो चकरा गई कि मैं हूँ कहाँ फिर एकदम याद आ...
# 4  एक असीम नीले संसार के बीचोंबीच , जिसे लोग सागर...
#
#                                                  tgt
# 0                                          Tortoise.
# 1  When my eyes opened in the morning, the sun wa...
# 2                Surprised, I looked around myself.
# 3  First I was wondering where I was, then I reme...
# 4  In the middle of an infinite blue world, which...

# %%
keystrokes = pd.read_csv('data/mt.dockeystroke.csv')
keystrokes.head()
# Out:
#     id                                      translatedSet  \
# 0  339   Test User | Jungle Brew MT L4 | Hindi -> English
# 1  338  Test User | At Least I'm Ok MT L3 | Hindi -> E...
# 2  337         Test User 301 | Monsoon | Hindi -> English
# 3  336  Test User 301 | Whats That Smell PE L3 | Hindi...
# 4  335  Test User 301 | A Helping Hand BL L4 | Hindi -...
#
#                                      keystrokeseries trump
# 0  [['Default Layout', 1], [1, 8872], ['card37', ...     Y
# 1  [['Default Layout', 2], [1, 3919], ['card42', ...     Y
# 2  [['Default Layout', 2], [1, 7694], ['card0', 7...     Y
# 3  [['Default Layout', 4], [1, 16561], ['card0', ...     Y
# 4  [['Default Layout', 2], [1, 8334], ['card1', 8...     Y

# %%
def break_user(x):
    xs1 = x.split('|')
    
    if len(xs1) > 1:
        return xs1[0]
        
def breakdown_level(x):
    xs1 = x.split('|')
    if len(xs1) > 1:
        xs2 = xs1[1].split(' ')
        xs2 = list(filter(None, xs2))
        if len(xs2) >= 3:
            if re.match(r"L\d", xs2[-1]):
                return xs2[-1]
    return ''

def breakdown_type(x):
    xs1 = x.split('|')
    if len(xs1) > 1:
        xs2 = xs1[1].split(' ')
        xs2 = list(filter(None, xs2))
        if len(xs2) >= 3:
            if re.match(r"L\d", xs2[-1]):
                return xs2[-2]
    return ''

def breakdown_story(x):
    xs1 = x.split('|')
    if len(xs1) > 1:
        xs2 = xs1[1].split(' ')
        xs2 = list(filter(None, xs2))
        if len(xs2) >= 3:
            if re.match(r"L\d", xs2[-1]):
                return ' '.join(xs2[:-2])
    return ''

# %%
trans_pairs['user'] = trans_pairs['translatedSet'].apply(lambda x: break_user(x))
trans_pairs['type'] = trans_pairs['translatedSet'].apply(lambda x: breakdown_type(x))
trans_pairs['level'] = trans_pairs['translatedSet'].apply(lambda x: breakdown_level(x))
trans_pairs['story'] = trans_pairs['translatedSet'].apply(lambda x: breakdown_story(x))

keystrokes['user'] = keystrokes['translatedSet'].apply(lambda x: break_user(x))
keystrokes['type'] = keystrokes['translatedSet'].apply(lambda x: breakdown_type(x))
keystrokes['level'] = keystrokes['translatedSet'].apply(lambda x: breakdown_level(x))
keystrokes['story'] = keystrokes['translatedSet'].apply(lambda x: breakdown_story(x))
keystrokes['total_keys'] = keystrokes['keystrokeseries'].apply(lambda x: len(ast.literal_eval(x)))
keystrokes['total_time'] = keystrokes['keystrokeseries'].apply(lambda x: ast.literal_eval(x)[-1][1])

# %%
list_users = list(trans_pairs['user'].unique())
list_stories = list(trans_pairs['story'].unique())

# %%
def actions_to_dict_keystrokes(actions):
    keydict = {}
    for a in range(len(actions)):
        if type(actions[a][0]) == str:
            if actions[a][0] not in keydict:
                keydict[actions[a][0]] = {}
            sub = 1
            while True:
                if a + sub < len(actions):
                    if actions[a][1] not in keydict[actions[a][0]]:
                        keydict[actions[a][0]][actions[a][1]] = []
                    if type(actions[a + sub][0]) == str:
                        break
                    keydict[actions[a][0]][actions[a][1]].append(actions[a + sub])
                    sub += 1
                else:
                    break
    return keydict

# %%
actions_to_dict_keystrokes([
  [
    "Default Layout",
    0
  ],
  [
    1,
    1134
  ],
  [
    "card0",
    1143
  ],
  [
    1,
    2530
  ],
  [
    "card1",
    2542
  ],
  [
    1,
    3386
  ],
  [
    "card2",
    3395
  ],
  [
    1,
    4394
  ],
  [
    "card3",
    4400
  ],
  [
    1,
    5050
  ],
  [
    "card4",
    5056
  ],
  [
    1,
    5714
  ],
  [
    "card5",
    5718
  ],
  [
    1,
    7050
  ],
  [
    "card6",
    7056
  ],
  [
    1,
    54019
  ],
  [
    "card7",
    54033
  ],
  [
    1,
    55274
  ],
  [
    "card8",
    55279
  ],
  [
    1,
    57402
  ],
  [
    "card9",
    57409
  ],
  [
    "card9",
    424954
  ],
  [
    1,
    424962
  ],
  [
    "card10",
    424971
  ],
  [
    1,
    426001
  ],
  [
    "card11",
    426008
  ],
  [
    1,
    426888
  ],
  [
    "card12",
    426895
  ],
  [
    1,
    427761
  ],
  [
    "card13",
    427767
  ],
  [
    1,
    428257
  ],
  [
    "card14",
    428263
  ],
  [
    1,
    429416
  ],
  [
    "card16",
    429422
  ],
  [
    1,
    431104
  ],
  [
    "card27",
    431113
  ],
  [
    1,
    432989
  ],
  [
    "card39",
    432996
  ],
  [
    1,
    433672
  ],
  [
    "card40",
    433679
  ]
])
# Out:
# {'Default Layout': {0: [[1, 1134]]},
#  'card0': {1143: [[1, 2530]]},
#  'card1': {2542: [[1, 3386]]},
#  'card2': {3395: [[1, 4394]]},
#  'card3': {4400: [[1, 5050]]},
#  'card4': {5056: [[1, 5714]]},
#  'card5': {5718: [[1, 7050]]},
#  'card6': {7056: [[1, 54019]]},
#  'card7': {54033: [[1, 55274]]},
#  'card8': {55279: [[1, 57402]]},
#  'card9': {57409: [], 424954: [[1, 424962]]},
#  'card10': {424971: [[1, 426001]]},
#  'card11': {426008: [[1, 426888]]},
#  'card12': {426895: [[1, 427761]]},
#  'card13': {427767: [[1, 428257]]},
#  'card14': {428263: [[1, 429416]]},
#  'card16': {429422: [[1, 431104]]},
#  'card27': {431113: [[1, 432989]]},
#  'card39': {432996: [[1, 433672]]},
#  'card40': {}}

# %%
keystrokes['keydict'] = keystrokes['keystrokeseries'].apply(lambda x: actions_to_dict_keystrokes(ast.literal_eval(x)))

# %%
for user in list_users:
    for story in list_stories:
        try:
            count = 0
            df = trans_pairs[(trans_pairs['user'].str.contains(user)) & (trans_pairs['story'].str.contains(story))]
            series = keystrokes[(keystrokes['user'].str.contains(user)) & keystrokes['story'].str.contains(story)]['keydict'].values[0]
            count = 0
            for index, row in df.iloc[::-1].iterrows():
                card = 'card' +  str(count)
                if card in series:
                    trans_pairs.loc[trans_pairs['id'] == row['id'], "repeat"] = len(series[card])
                    trans_pairs.loc[trans_pairs['id'] == row['id'], "actions"] = str(series[card])
                else:
                    trans_pairs.loc[trans_pairs['id'] == row['id'], "repeat"] = -1
                    trans_pairs.loc[trans_pairs['id'] == row['id'], "actions"] = '{}'
                count += 1
        except Exception as e:
            print(e)
# Out:
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# first argument must be string or compiled pattern
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0

# %%
trans_pairs.head()

# %%
trans_pairs[(trans_pairs['user'].str.contains('User 401')) & (trans_pairs['story'].str.contains('Turtle Story'))]
# Out:
#       id                                      translatedSet  \
# 0   8698  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 1   8697  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 2   8696  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 3   8695  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 4   8694  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 5   8693  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 6   8692  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 7   8691  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 8   8690  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 9   8689  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 10  8688  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 11  8687  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 12  8686  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 13  8685  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 14  8684  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 15  8683  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 16  8682  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 17  8681  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 18  8680  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 19  8679  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 20  8678  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 21  8677  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 22  8676  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 23  8675  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 24  8674  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 25  8673  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 26  8672  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 27  8671  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 28  8670  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 29  8669  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 30  8668  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 31  8667  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 32  8666  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 33  8665  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 34  8664  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 35  8663  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 36  8662  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 37  8661  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 38  8660  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 39  8659  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 40  8658  Test User 401 | Turtle Story PE L4 | Hindi -> ...
#
#                                                   src  \
# 0                                                कछुआ
# 1   सुबह जब मेरी आँख खुली तो आसमान में सूरज चम - च...
# 2                    हैरान होकर मैंने अपने आसपास देखा
# 3   पहले तो चकरा गई कि मैं हूँ कहाँ फिर एकदम याद आ...
# 4   एक असीम नीले संसार के बीचोंबीच , जिसे लोग सागर...
# 5   चारों ओर नीला , हरा पानी लहरा रहा था और सूरज क...
# 6   मैनें अपने मीनपक्षों ( फ़्लिपर ) १ को पेट त¬ले ...
# 7                  मुझे नहीं मालूम था कि मैं कहाँ हूँ
# 8   लेकिन जब आसपास नर्म - नर्म धूप बिछी हो और पेटप...
# 9                गुनगुनी धूप में मैं भी गुनगुनी हो गई
# 10                      एक नई स्फूर्ति आ गई थी मुझमें
# 11  काश कि मैं हमेशा - हमेशा के लिए यहीं रह सकती -...
# 12                  एक बहुत बड़ी मछली उनके पीछे पड़ी थी
# 13                               बहुत भूखी लगती थी वह
# 14                                     मेरा शक सही था
# 15      जब उसकी नज़र मुझ पर पड़ी तो उसकी बाँछें खिल गईं
# 16                                             भई वाह
# 17          आज तो नन्हे कछुए का शोरबा मिलेगा खाने में
# 18                             शायद वह यही सोच रही थी
# 19  १ ( फ़्लिपर ) कछुए के पर जिनके सहारे वह पानी मे...
# 20           तब तो मानो मैं सर पर पैर रख कर तैरने लगी
# 21  आगे - आगे मैं और पीछे - पीछे बड़े - बड़े दाँतों ...
# 22                         तैरते - तैरते थक गई थी मैं
# 23       तभी मुझे समुद्री शैवाल का एक बेड़ा दिखाई दिया
# 24  शैवाल और बहती हुई लकड़ी का यह बेड़ा न जाने कहाँ ...
# 25  इस बेड़े पर समुद्र में रहने वाले छोटे - बड़े जीव...
# 26             मैंने राहत की साँस ली और चढ़ गई बेड़े पर
# 27  इस बेड़े पर मैं सालों - साल रहने वाली थी - सुखी...
# 28  बेड़े पर मेरा जीवन किसी विश्व - यात्रा से कम नह...
# 29                                  बहुत मज़ा आ रहा था
# 30                   लेकिन अब मैं बड़ी भी तो हो रही थी
# 31                बाहर की दुनिया की सैर करना चाहती थी
# 32  प्रवालभित्ति या रीफ़ के बारे में मैंने कैसी - क...
# 33                        बहुत सारे कछुए रहते थे वहाँ
# 34                सब कहते थे कि रीफ़ सागर का परीलोक है
# 35  कितने ही रंग - बिरंगे , चमकीले प्राणियों का घर...
# 36            लेकिन मुझे कैसे पता चलेगा कि वह कहाँ है
# 37                            फिर एकाएक अँधेरा छा गया
# 38                   एक बहुत बड़ी छाया ने मुझे ढक लिया
# 39                          डर के मारे मैंने ऊपर देखा
# 40  वह एक विशालकाय कछुआ था - इतना बड़ा तो मैंने कभी...
#
#                                                   tgt            user type  \
# 0                                           Tortoise.  Test User 401    PE
# 1   When my eyes opened in the morning, the sun wa...  Test User 401    PE
# 2                 Surprised, I looked around myself.   Test User 401    PE
# 3   First I was wondering where I was, then I reme...  Test User 401    PE
# 4   In the middle of an infinite blue world, which...  Test User 401    PE
# 5   Blue, green water was sparkling all around and...  Test User 401    PE
# 6   I collected my meenpaksh (flipper) 1 in my sto...  Test User 401    PE
# 7                         I didn't know where I was.   Test User 401    PE
# 8   But when there is soft sunshine around and the...  Test User 401    PE
# 9                I also became warm in the warm sun.   Test User 401    PE
# 10                      A new vigour had come in me.   Test User 401    PE
# 11  Wish I could always stay here - was just think...  Test User 401    PE
# 12                  A very big fish was after them.    Test User 401    PE
# 13                           She looked very hungry.   Test User 401    PE
# 14                               My doubt was right.   Test User 401    PE
# 15  When his eyes fell on me, he was extremely hap...  Test User 401    PE
# 16                                     Brother great!  Test User 401    PE
# 17  Today , the curry of the little tortoise will ...  Test User 401    PE
# 18                  Maybe she was thinking the same.   Test User 401    PE
# 19  1 (flipper) tortoise depending on whom it swim...  Test User 401    PE
# 20  Then , as if I started swimming with my feet o...  Test User 401    PE
# 21     Me ahead and that jaw of big teeth behind me.   Test User 401    PE
# 22                             I was tired swimming.   Test User 401    PE
# 23                Then I saw a fleet of marine algae.  Test User 401    PE
# 24  Who knows where this floating fleet of algae a...  Test User 401    PE
# 25  Big and small animals live on the fleet travel...  Test User 401    PE
# 26                  I have made relief and a murmur ,  Test User 401    PE
# 27  I was going to live at the fleet for years- ha...  Test User 401    PE
# 28  Life at fleet was not less than a foreign trav...  Test User 401    PE
# 29                                  It was great fun.  Test User 401    PE
# 30                      But now i was also growing up  Test User 401    PE
# 31                       Wanted to travel the world..  Test User 401    PE
# 32  I had heard many funny stories about coral reef..  Test User 401    PE
# 33                         Many tortoises live there.  Test User 401    PE
# 34  All of them said the reef was fairy world of t...  Test User 401    PE
# 35  The house of so many colourful , bright animal...  Test User 401    PE
# 36                  But how will i know where is it??  Test User 401    PE
# 37                 Then darkness surrounded suddenly.  Test User 401    PE
# 38                      A very big shadow covered me.  Test User 401    PE
# 39                               I looked up in fear.  Test User 401    PE
# 40  That was a giant tortoise. I haven't seen so big.  Test User 401    PE
#
#    level         story  repeat actions
# 0     L4  Turtle Story    -1.0      {}
# 1     L4  Turtle Story    -1.0      {}
# 2     L4  Turtle Story    -1.0      {}
# 3     L4  Turtle Story    -1.0      {}
# 4     L4  Turtle Story    -1.0      {}
# 5     L4  Turtle Story    -1.0      {}
# 6     L4  Turtle Story    -1.0      {}
# 7     L4  Turtle Story    -1.0      {}
# 8     L4  Turtle Story    -1.0      {}
# 9     L4  Turtle Story    -1.0      {}
# 10    L4  Turtle Story    -1.0      {}
# 11    L4  Turtle Story    -1.0      {}
# 12    L4  Turtle Story    -1.0      {}
# 13    L4  Turtle Story    -1.0      {}
# 14    L4  Turtle Story    -1.0      {}
# 15    L4  Turtle Story    -1.0      {}
# 16    L4  Turtle Story    -1.0      {}
# 17    L4  Turtle Story    -1.0      {}
# 18    L4  Turtle Story    -1.0      {}
# 19    L4  Turtle Story    -1.0      {}
# 20    L4  Turtle Story    -1.0      {}
# 21    L4  Turtle Story    -1.0      {}
# 22    L4  Turtle Story    -1.0      {}
# 23    L4  Turtle Story    -1.0      {}
# 24    L4  Turtle Story    -1.0      {}
# 25    L4  Turtle Story    -1.0      {}
# 26    L4  Turtle Story    -1.0      {}
# 27    L4  Turtle Story    -1.0      {}
# 28    L4  Turtle Story    -1.0      {}
# 29    L4  Turtle Story    -1.0      {}
# 30    L4  Turtle Story    -1.0      {}
# 31    L4  Turtle Story    -1.0      {}
# 32    L4  Turtle Story    -1.0      {}
# 33    L4  Turtle Story    -1.0      {}
# 34    L4  Turtle Story    -1.0      {}
# 35    L4  Turtle Story    -1.0      {}
# 36    L4  Turtle Story    -1.0      {}
# 37    L4  Turtle Story    -1.0      {}
# 38    L4  Turtle Story    -1.0      {}
# 39    L4  Turtle Story    -1.0      {}
# 40    L4  Turtle Story    -1.0      {}

# %%
(keystrokes[(keystrokes['user'].str.contains('User 401')) & (keystrokes['story'].str.contains('Turtle Story'))]["keydict"].values[0])
# Out:
# {'Default Layout': {1: [[1, 6392]]},
#  'card4': {6427: [[1, 10333], [1, 11403]]},
#  'card5': {11410: [[1, 16206]]},
#  'card8': {16225: [[1, 20678]], 59762: [[1, 64436]]},
#  'card7': {20693: [[1, 21932]], 64451: [[1, 65987]]},
#  'card9': {21947: [[1, 24285]], 58328: [[1, 59748]]},
#  'card10': {24300: [[1, 27501]], 56731: [[1, 58307]]},
#  'card12': {27515: [[1, 29492], [1, 30308]], 54667: [[1, 56716]]},
#  'card13': {30315: [[1, 33327], [1, 34269]], 51687: [[1, 54651]]},
#  'card15': {34275: [[1, 37916]]},
#  'card14': {37931: [[1, 41004]]},
#  'card16': {41018: [[1, 51670]]},
#  'card6': {66004: [[1, 76445],
#    [46, 78507],
#    [1, 80242],
#    [84, 83216],
#    [72, 83488],
#    [69, 83632],
#    [32, 83712],
#    [82, 84824],
#    [69, 85168],
#    [69, 85336],
#    [70, 85592],
#    [32, 85728],
#    [87, 85984],
#    [65, 86264],
#    [83, 86577],
#    [32, 86816],
#    [70, 89488],
#    [65, 89712],
#    [73, 89920],
#    [82, 90160],
#    [89, 90248],
#    [32, 90504],
#    [87, 90688],
#    [73, 90848],
#    [79, 90857],
#    [82, 90968],
#    [8, 91600],
#    [8, 91896],
#    [8, 92072],
#    [73, 92416],
#    [82, 92576],
#    [75, 92712],
#    [8, 93088],
#    [8, 93360],
#    [8, 93944],
#    [79, 94800],
#    [82, 94992],
#    [75, 95144],
#    [76, 95148],
#    [68, 95256],
#    [8, 96048],
#    [8, 96200],
#    [8, 96440],
#    [76, 96640],
#    [68, 96752],
#    [32, 96848],
#    [79, 96992],
#    [70, 97106],
#    [32, 97144],
#    [84, 97320],
#    [72, 97376],
#    [82, 97512],
#    [69, 97516],
#    [32, 97562],
#    [83, 97808],
#    [8, 98136],
#    [8, 98248],
#    [8, 98384],
#    [8, 98512],
#    [69, 98664],
#    [32, 98856],
#    [83, 98976],
#    [69, 99128],
#    [65, 99360],
#    [190, 99464],
#    [32, 99496],
#    [1, 102349],
#    [1, 104399]]}}
