# %%
import pandas as pd
import re
import ast
import numpy as np

# %%
trans_sets = pd.read_csv('data/mt.corpusdivide.csv')

# %%
trans_pairs = pd.read_csv('data/mt.trans_pairs.csv')
len(trans_pairs)
# Out:
# 7023

# %%
keystrokes = pd.read_csv('data/mt.dockeystroke.csv')
keystrokes.head()
# Out:
#     id                                      translatedSet  \
# 0  339   Test User | Jungle Brew MT L4 | Hindi -> English
# 1  338  Test User | At Least I'm Ok MT L3 | Hindi -> E...
# 2  337         Test User 301 | Monsoon | Hindi -> English
# 3  336  Test User 301 | Whats That Smell PE L3 | Hindi...
# 4  335  Test User 301 | A Helping Hand BL L4 | Hindi -...
#
#                                      keystrokeseries trump
# 0  [['Default Layout', 1], [1, 8872], ['card37', ...     Y
# 1  [['Default Layout', 2], [1, 3919], ['card42', ...     Y
# 2  [['Default Layout', 2], [1, 7694], ['card0', 7...     Y
# 3  [['Default Layout', 4], [1, 16561], ['card0', ...     Y
# 4  [['Default Layout', 2], [1, 8334], ['card1', 8...     Y

# %%
# Out:
# {1: 141,
#  13: 40,
#  190: 39,
#  46: 4,
#  17: 49,
#  67: 45,
#  40: 59,
#  38: 6,
#  8: 238,
#  83: 109,
#  32: 378,
#  73: 85,
#  78: 98,
#  16: 111,
#  85: 59,
#  65: 126,
#  75: 25,
#  76: 79,
#  68: 74,
#  87: 52,
#  84: 177,
#  79: 138,
#  72: 114,
#  69: 227,
#  70: 26,
#  82: 90,
#  188: 25,
#  66: 24,
#  86: 23,
#  89: 23,
#  88: 1,
#  77: 32,
#  71: 30,
#  3: 3,
#  80: 11,
#  189: 2,
#  191: 7,
#  222: 41,
#  48: 1,
#  37: 1,
#  49: 1,
#  81: 1,
#  186: 1}

# %%
# Out:
# id        136
# corpus    136
# src       136
# dtype: int64

# %%
def breakdown_level(x):
    xs1 = x.split('|')
    if len(xs1) > 1:
        xs2 = xs1[1].split(' ')
        xs2 = list(filter(None, xs2))
        if len(xs2) >= 3:
            if re.match(r"L\d", xs2[-1]):
                return xs2[-1]
    return ''

def breakdown_type(x):
    xs1 = x.split('|')
    if len(xs1) > 1:
        xs2 = xs1[1].split(' ')
        xs2 = list(filter(None, xs2))
        if len(xs2) >= 3:
            if re.match(r"L\d", xs2[-1]):
                return xs2[-2]
    return ''

def breakdown_story(x):
    xs1 = x.split('|')
    if len(xs1) > 1:
        xs2 = xs1[1].split(' ')
        xs2 = list(filter(None, xs2))
        if len(xs2) >= 3:
            if re.match(r"L\d", xs2[-1]):
                return ' '.join(xs2[:-2])
    return ''

# %%
trans_pairs['type'] = trans_pairs['translatedSet'].apply(lambda x: breakdown_type(x))
trans_pairs['level'] = trans_pairs['translatedSet'].apply(lambda x: breakdown_level(x))
trans_pairs['story'] = trans_pairs['translatedSet'].apply(lambda x: breakdown_story(x))

keystrokes['type'] = keystrokes['translatedSet'].apply(lambda x: breakdown_type(x))
keystrokes['level'] = keystrokes['translatedSet'].apply(lambda x: breakdown_level(x))
keystrokes['story'] = keystrokes['translatedSet'].apply(lambda x: breakdown_story(x))
# trans_pairs.head()

# %%
import seaborn as sns
sns.set(style="darkgrid")

df = sns.load_dataset("titanic")
pal = dict(male="#6495ED", female="#F08080")
g = sns.lmplot(x="age", y="survived", col="sex", hue="sex", data=df,
               palette=pal, y_jitter=.02, logistic=True)
g.set(xlim=(0, 80), ylim=(-.05, 1.05))
g

# %%
keystrokes['total_keys'] = keystrokes['keystrokeseries'].apply(lambda x: len(ast.literal_eval(x)))
keystrokes['total_time'] = keystrokes['keystrokeseries'].apply(lambda x: ast.literal_eval(x)[-1][1])

# %%
keystrokes.head()
# Out:
#     id                                      translatedSet  \
# 0  339   Test User | Jungle Brew MT L4 | Hindi -> English
# 1  338  Test User | At Least I'm Ok MT L3 | Hindi -> E...
# 2  337         Test User 301 | Monsoon | Hindi -> English
# 3  336  Test User 301 | Whats That Smell PE L3 | Hindi...
# 4  335  Test User 301 | A Helping Hand BL L4 | Hindi -...
#
#                                      keystrokeseries trump type level  \
# 0  [['Default Layout', 1], [1, 8872], ['card37', ...     Y   MT    L4
# 1  [['Default Layout', 2], [1, 3919], ['card42', ...     Y   MT    L3
# 2  [['Default Layout', 2], [1, 7694], ['card0', 7...     Y
# 3  [['Default Layout', 4], [1, 16561], ['card0', ...     Y   PE    L3
# 4  [['Default Layout', 2], [1, 8334], ['card1', 8...     Y   BL    L4
#
#               story  total_keys  total_time
# 0       Jungle Brew        3347     2342218
# 1   At Least I'm Ok        2900    76956234
# 2                           432      557295
# 3  Whats That Smell        3017     3658123
# 4    A Helping Hand        2717     2192266

# %%
def keystrokedict(numks):
    keys = {}
    for i in numks:
        if type(i[0]) != str:
            if i[0] in keys:
                keys[i[0]] += 1
            else:
                keys[i[0]] = 1
    return keys

numks = ast.literal_eval(keystrokes.iloc[1]['keystrokeseries'])
keystrokedict(numks)
# Out:
#   File "<ipython-input-106-850e557d9b30>", line 4
#     if type(i[0]) != str:
#      ^
# IndentationError: expected an indented block

# %%
new_keystrokes = keystrokes[['type', 'level', 'total_keys', 'total_time', 'story']]

#Drop empty fields
new_keystrokes['type'].replace('', np.nan, inplace=True)
new_keystrokes.dropna(subset=['type'], inplace=True)
new_keystrokes.head()
# Out:
# C:\Users\t-sesan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#   type level  total_keys  total_time             story
# 0   MT    L4        3347     2342218       Jungle Brew
# 1   MT    L3        2900    76956234   At Least I'm Ok
# 3   PE    L3        3017     3658123  Whats That Smell
# 4   BL    L4        2717     2192266    A Helping Hand
# 5   MT    L4        2978     3908143    A Helping Hand

# %%
len(new_keystrokes)
# Out:
# 172

# %%
# sns.set(style="ticks")

# df = sns.load_dataset("iris")
sns.regplot(x="total_keys", y="total_time", data=new_keystrokes[(new_keystrokes['level'] == 'L1') & (new_keystrokes['type'] == 'BL')])
sns.regplot(x="total_keys", y="total_time", data=new_keystrokes[(new_keystrokes['level'] == 'L1') & (new_keystrokes['type'] == 'PE')])
sns.regplot(x="total_keys", y="total_time", data=new_keystrokes[(new_keystrokes['level'] == 'L1') & (new_keystrokes['type'] == 'MT')])

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
trans_pairs['user'] = trans_pairs['translatedSet'].apply(lambda x: x.split('|')[0])

# %%
trans_pairs.head()
# Out:
#      id                                      translatedSet  \
# 0  8698  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 1  8697  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 2  8696  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 3  8695  Test User 401 | Turtle Story PE L4 | Hindi -> ...
# 4  8694  Test User 401 | Turtle Story PE L4 | Hindi -> ...
#
#                                                  src  \
# 0                                               कछुआ
# 1  सुबह जब मेरी आँख खुली तो आसमान में सूरज चम - च...
# 2                   हैरान होकर मैंने अपने आसपास देखा
# 3  पहले तो चकरा गई कि मैं हूँ कहाँ फिर एकदम याद आ...
# 4  एक असीम नीले संसार के बीचोंबीच , जिसे लोग सागर...
#
#                                                  tgt type level  \
# 0                                          Tortoise.   PE    L4
# 1  When my eyes opened in the morning, the sun wa...   PE    L4
# 2                Surprised, I looked around myself.    PE    L4
# 3  First I was wondering where I was, then I reme...   PE    L4
# 4  In the middle of an infinite blue world, which...   PE    L4
#
#              user
# 0  Test User 401
# 1  Test User 401
# 2  Test User 401
# 3  Test User 401
# 4  Test User 401

# %%
# trans_pairs['details'] = ' ((( ' + trans_pairs['type'] + ' ::: ' + trans_pairs['level'] + ' ::: ' + trans_pairs['user'] + ' ::: ' + trans_pairs['tgt'] + ' ))) '

# %%
# trans_pairs[trans_pairs['details'].isnull()] = ''

# %%
# agg_pairs = trans_pairs.groupby('src').agg({'details': lambda x: ' ||| '.join(x)})

# %%
# agg_pairs.iloc[200]['details']

# %%
trans_pairs[trans_pairs['type'] == 'BL']
# Out:
#          id                                      translatedSet  \
# 746    7948  Test User 301 | How to be an Otter BL L3 | Hin...
# 747    7947  Test User 301 | How to be an Otter BL L3 | Hin...
# 748    7946  Test User 301 | How to be an Otter BL L3 | Hin...
# 749    7945  Test User 301 | How to be an Otter BL L3 | Hin...
# 750    7944  Test User 301 | How to be an Otter BL L3 | Hin...
# 751    7943  Test User 301 | How to be an Otter BL L3 | Hin...
# 752    7942  Test User 301 | How to be an Otter BL L3 | Hin...
# 753    7941  Test User 301 | How to be an Otter BL L3 | Hin...
# 754    7940  Test User 301 | How to be an Otter BL L3 | Hin...
# 755    7939  Test User 301 | How to be an Otter BL L3 | Hin...
# 756    7938  Test User 301 | How to be an Otter BL L3 | Hin...
# 757    7937  Test User 301 | How to be an Otter BL L3 | Hin...
# 758    7936  Test User 301 | How to be an Otter BL L3 | Hin...
# 759    7935  Test User 301 | How to be an Otter BL L3 | Hin...
# 760    7934  Test User 301 | How to be an Otter BL L3 | Hin...
# 761    7933  Test User 301 | How to be an Otter BL L3 | Hin...
# 762    7932  Test User 301 | How to be an Otter BL L3 | Hin...
# 763    7931  Test User 301 | How to be an Otter BL L3 | Hin...
# 764    7930  Test User 301 | How to be an Otter BL L3 | Hin...
# 765    7929  Test User 301 | How to be an Otter BL L3 | Hin...
# 766    7928  Test User 301 | How to be an Otter BL L3 | Hin...
# 767    7927  Test User 301 | How to be an Otter BL L3 | Hin...
# 768    7926  Test User 301 | How to be an Otter BL L3 | Hin...
# 769    7925  Test User 301 | How to be an Otter BL L3 | Hin...
# 770    7924  Test User 301 | How to be an Otter BL L3 | Hin...
# 771    7923  Test User 301 | How to be an Otter BL L3 | Hin...
# 772    7922  Test User 301 | How to be an Otter BL L3 | Hin...
# 773    7921  Test User 301 | How to be an Otter BL L3 | Hin...
# 774    7920  Test User 301 | How to be an Otter BL L3 | Hin...
# 775    7919  Test User 301 | How to be an Otter BL L3 | Hin...
# ...     ...                                                ...
# 5809  10080  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5810  10079  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5811  10078  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5812  10077  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5813  10076  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5814  10075  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5815  10074  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5816  10073  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5817  10072  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5818  10071  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5819  10070  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5820  10069  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5821  10068  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5822  10067  Test User 1201 | Under My Bed BL L2 | Hindi ->...
# 5823  10066  Test User 1201 | My Home BL L1 | Hindi -> English
# 5824  10065  Test User 1201 | My Home BL L1 | Hindi -> English
# 5825  10064  Test User 1201 | My Home BL L1 | Hindi -> English
# 5826  10063  Test User 1201 | My Home BL L1 | Hindi -> English
# 5827  10062  Test User 1201 | My Home BL L1 | Hindi -> English
# 5828  10061  Test User 1201 | My Home BL L1 | Hindi -> English
# 5829  10060  Test User 1201 | My Home BL L1 | Hindi -> English
# 5830  10059  Test User 1201 | My Home BL L1 | Hindi -> English
# 5831  10058  Test User 1201 | My Home BL L1 | Hindi -> English
# 5832  10057  Test User 1201 | My Home BL L1 | Hindi -> English
# 5833  10056  Test User 1201 | My Home BL L1 | Hindi -> English
# 5834  10055  Test User 1201 | My Home BL L1 | Hindi -> English
# 5835  10054  Test User 1201 | My Home BL L1 | Hindi -> English
# 5836  10053  Test User 1201 | My Home BL L1 | Hindi -> English
# 5837  10052  Test User 1201 | My Home BL L1 | Hindi -> English
# 5838  10051  Test User 1201 | My Home BL L1 | Hindi -> English
#
#                                                     src  \
# 746                                 ऊदबिलाव बनने के गुण
# 747                                          तैरना सीखो
# 748                           अच्छे तरीके से तैरना सीखो
# 749   ऐसा कि मछली पकड़ सको और किसी भी तरह के खतरे से...
# 750   इसमें तुम्हारे झिल्लीदार पैर और लंबी चप्पू जैस...
# 751                       अपनी रोएँदार खाल का ध्यान रखो
# 752   यह पानी को अन्दर नहीं जाने देता जिससे ठंडे पान...
# 753                  मछलियों के बारे में जानना ज़रूरी है
# 754   धीरे - धीरे तुम्हें मछलियों की गंध और बदबूदार ...
# 755   तुम्हें पानी में छोटी मछलियाँ और बड़ी मछलियाँ ...
# 756   ऐसी मछलियाँ भी तुम देखोगे जो साँप की तरह लगती हैं
# 757   यहाँ तक कि कुछ ऐसी भी होंगी जिनकी बिल्ली की तर...
# 758                  सभी मछलियों को पकड़ना आसान नहीं है
# 759         पर याद रखो , कभी भी मरी हुई मछली को मत खाना
# 760                                  नदी तुम्हारा घर है
# 761   यहीं , नदी के तट पर , तुम अपने परिवार के लिए म...
# 762            एक परिवार की तरह , तुम एक समूह में रहोगे
# 763                    तुम एक साथ शिकार करोगे और खेलोगे
# 764                    तुम एक - दूसरे की रक्षा भी करोगे
# 765                    घर के बड़े बच्चों की रक्षा करेंगे
# 766   अपने बड़ों की बात सुनो , क्योंकि नदी के बारे म...
# 767                     नदी तुम्हारा खेल का मैदान भी है
# 768   यहाँ तुम्हारे खोदने के लिए रेत है , छिपने के ल...
# 769   चट्टानें भी हैं जिन पर लेट कर तुम झपकी ले सकते हो
# 770   नदी में और प्राणी भी होंगे , तुम्हें उनके साथ ...
# 771   तुम्हारे साथ नदी में विशाल बगुले , शर्मीले कछु...
# 772               दुष्ट मगरमच्छों को अकेले रहना पसंद है
# 773                               उन्हें परेशान मत करना
# 774   मछुआरा तुम्हारा मित्र हो सकता है , पर उसके जाल...
# 775   अपने परिवार के भरण - पोषण के लिए , हमारी ही तर...
# ...                                                 ...
# 5809                              दरवाज़े पर माँ खड़ी हैं
# 5810                                   क्या बात है बेटा
# 5811                                       माँ कहती हैं
# 5812                                     मुझे बुलाया था
# 5813                       मैं शेर की ओर इशारा करता हूँ
# 5814    माँ झुकती हैं और शेर को खींचकर बाहर निकालती हैं
# 5815                                                अरे
# 5816                              कोई शेर - वेर नहीं है
# 5817              यह तो मेरा मोटा पीला - काला स्वेटर है
# 5818             इसके बटन शेर की आँखों की तरह चमकते हैं
# 5819                               मैं तो ऐसे ही डर गया
# 5820                           माँ मुझे पानी पिलाती हैं
# 5821                                   अब मैं सो जाऊँगा
# 5822           जंगल में असली शेरों के सपने जो देखने हैं
# 5823                                      यह मेरा घर है
# 5824          मैं यहाँ अपने पूरे परिवार के साथ रहती हूँ
# 5825              हम अपने जूते और चप्पल यहाँ उतारते हैं
# 5826                   यहाँ हम अपने हाथ - मुँह धोते हैं
# 5827                  मैं अपने कपड़े खूँटी पर टाँगती हूँ
# 5828            मेरे दादा जी अपनी छड़ी कोने में रखते हैं
# 5829                   हम अपनी चटाइयाँ भी वहीं रखते हैं
# 5830         मेरे पिता जी अपनी मोटरसाइकिल बाहर रखते हैं
# 5831           लेकिन उनका हेल्मेट अलमारी के ऊपर रहता है
# 5832   मेरी माँ और दादी अपनी साड़ियाँ बक्से में रखती हैं
# 5833                  स्वादिष्ट खाना रसोईघर में पकता है
# 5834        जब ठंड पड़ती है तो हम रज़ाइयाँ निकाल लेते हैं
# 5835        जब गर्मी पड़ती है तो हम एक पंखा चला लेते हैं
# 5836  जब हमारे यहाँ ख़ास मेहमान आते हैं तो हम कुर्सिय...
# 5837                 तुम मेरे घर ज़रूर आना , मुझसे मिलने
# 5838                                          जल्दी आना
#
#                                                     tgt type level  \
# 746                     Must have features of a beaver.   BL    L3
# 747                                      Learn to swim.   BL    L3
# 748                                 Learn to swim well.   BL    L3
# 749   So that you can catch fishes and save yourselv...   BL    L3
# 750   Your webbed legs and long paddle-like tail wil...   BL    L3
# 751                       Take care of your furry skin.   BL    L3
# 752   It doesn't allow water to enter inside which m...   BL    L3
# 753           It is important to know about the fishes.   BL    L3
# 754   Slowly, you will start liking the smell of the...   BL    L3
# 755     You will see small and big fishes in the water.   BL    L3
# 756   You will also see some fishes that look like s...   BL    L3
# 757   Infact, there will be some with mustache like ...   BL    L3
# 758              It's not easy to catch all the fishes.   BL    L3
# 759                But remember, never eat a dead fish.   BL    L3
# 760                             The river is your home.   BL    L3
# 761   Here, on the river bank, you will dig holes fo...   BL    L3
# 762         You will remain in one group like a family.   BL    L3
# 763                    You will hunt and play together.   BL    L3
# 764                  You will also protect each other.    BL    L3
# 765               The leaders will protect the children   BL    L3
# 766   Listen to your leaders as they know everything...   BL    L3
# 767                  The river is also your playground.   BL    L3
# 768   There is a lot of sand for you to dig and a lo...   BL    L3
# 769   There are also big rocks on which you can lie ...   BL    L3
# 770   There will be many more creatures in the river...   BL    L3
# 771   There will be big cranes, shy turtles, weird l...   BL    L3
# 772                Nasty crocodiles like to stay alone.   BL    L3
# 773                                   Don't annoy them.   BL    L3
# 774   The fisherman can your friend, but stay carefu...   BL    L3
# 775   Just like us, the fisherman too require fishes...   BL    L3
# ...                                                 ...  ...   ...
# 5809                                                NaN   BL    L2
# 5810                                                NaN   BL    L2
# 5811                                                NaN   BL    L2
# 5812                                                NaN   BL    L2
# 5813                                                NaN   BL    L2
# 5814                                                NaN   BL    L2
# 5815                                                NaN   BL    L2
# 5816                                                NaN   BL    L2
# 5817                                                NaN   BL    L2
# 5818                                                NaN   BL    L2
# 5819                                                NaN   BL    L2
# 5820                                                NaN   BL    L2
# 5821                                                NaN   BL    L2
# 5822                                                NaN   BL    L2
# 5823                                                NaN   BL    L1
# 5824                                                NaN   BL    L1
# 5825                                                NaN   BL    L1
# 5826                                                NaN   BL    L1
# 5827                                                NaN   BL    L1
# 5828                                                NaN   BL    L1
# 5829                                                NaN   BL    L1
# 5830                                                NaN   BL    L1
# 5831                                                NaN   BL    L1
# 5832                                                NaN   BL    L1
# 5833                                                NaN   BL    L1
# 5834                                                NaN   BL    L1
# 5835                                                NaN   BL    L1
# 5836                                                NaN   BL    L1
# 5837                                                NaN   BL    L1
# 5838                                                NaN   BL    L1
#
#                  user
# 746    Test User 301
# 747    Test User 301
# 748    Test User 301
# 749    Test User 301
# 750    Test User 301
# 751    Test User 301
# 752    Test User 301
# 753    Test User 301
# 754    Test User 301
# 755    Test User 301
# 756    Test User 301
# 757    Test User 301
# 758    Test User 301
# 759    Test User 301
# 760    Test User 301
# 761    Test User 301
# 762    Test User 301
# 763    Test User 301
# 764    Test User 301
# 765    Test User 301
# 766    Test User 301
# 767    Test User 301
# 768    Test User 301
# 769    Test User 301
# 770    Test User 301
# 771    Test User 301
# 772    Test User 301
# 773    Test User 301
# 774    Test User 301
# 775    Test User 301
# ...               ...
# 5809  Test User 1201
# 5810  Test User 1201
# 5811  Test User 1201
# 5812  Test User 1201
# 5813  Test User 1201
# 5814  Test User 1201
# 5815  Test User 1201
# 5816  Test User 1201
# 5817  Test User 1201
# 5818  Test User 1201
# 5819  Test User 1201
# 5820  Test User 1201
# 5821  Test User 1201
# 5822  Test User 1201
# 5823  Test User 1201
# 5824  Test User 1201
# 5825  Test User 1201
# 5826  Test User 1201
# 5827  Test User 1201
# 5828  Test User 1201
# 5829  Test User 1201
# 5830  Test User 1201
# 5831  Test User 1201
# 5832  Test User 1201
# 5833  Test User 1201
# 5834  Test User 1201
# 5835  Test User 1201
# 5836  Test User 1201
# 5837  Test User 1201
# 5838  Test User 1201
#
# [1706 rows x 7 columns]
